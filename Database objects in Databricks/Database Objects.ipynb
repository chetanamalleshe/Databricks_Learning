-- %% [markdown]
-- ![](/Volumes/datamaster/bronze/image/Screenshot 2026-09-16 235012.png)

-- %%
create catalog DataMaster;

-- %%
create schema if not exists DataMaster.Bronze;

-- %%
Use catalog datamaster;
use schema bronze;

-- %% [markdown]
-- ![](/Volumes/datamaster/bronze/image/Screenshot 2026-09-16 233528.png)

-- %%
create volume if not exists data;

-- %%
alter volume data rename to image;

-- %%
create table employee (id int, name varchar(20), age int, city string)

-- %%
show tables;

-- %%
insert into employee values (1,"chetana",25,"pune");

-- %%
select * from employee;

-- %%
delete from employee where id=1;
select * from employee;

-- %%
create volume if not exists raw_csv_file;
show volumes;

-- %% [markdown]
-- ![](/Volumes/datamaster/bronze/raw_csv_file/Excel_Practice_Dataset.xlsx)

-- %% [markdown]
-- [](/Volumes/datamaster/bronze/raw_csv_file/Excel_Practice_Dataset.xlsx)

-- %% [markdown]
-- [](/Volumes/datamaster/bronze/raw_csv_file/Excel_Practice_Dataset.xlsx)
