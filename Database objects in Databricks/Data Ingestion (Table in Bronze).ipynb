-- %%
/Volumes/datamaster/bronze/raw_csv_file

-- %% [markdown]
-- Data Ingestion (Table)
-- 1. UI(Volume)
-- 2. Pyspark Dataframe
-- 3. sql - read_file

-- %% [markdown]
-- By Using Pyspark

-- %%
%python
df = spark.read.csv("/Volumes/datamaster/bronze/raw_csv_file", header=True,inferSchema=True)

-- %%
use catalog datamaster;
use schema bronze;

-- %%
create table data as  select *, current_timestamp as ingestion_date from read_files('/Volumes/datamaster/bronze/raw_csv_file', format=>'csv')
