-- %%
use catalog datamaster;
use schema bronze;

-- %%
Show schemas in all catalogs;

-- %%
describe schema extended identifier('datamaster.bronze');

-- %%
describe table extended datamaster.bronze.data;

-- %%
describe volume datamaster.bronze.raw_csv_file;

-- %%
list "/Volumes/datamaster/bronze/raw_csv_file";

-- %%
select current_catalog(), current_schema();
